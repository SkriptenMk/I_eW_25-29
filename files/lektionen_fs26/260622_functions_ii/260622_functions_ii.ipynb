# %% [markdown]
# # Functions: Exercises

# %% [markdown]
# To drill the implementation of Python functions here some exercises.
# Because the exercises use trigonometric functions, we need the `math`
# library. The `math` library is a standard library. This means it is
# shipped with the standard Python installation. Therefore, it can be
# imported without additional installations. For a list of functions
# provided by the `math` library please visit the [Python
# documentation](https://docs.python.org/3/library/math.html).

# %%
import math

# %% [markdown]
# Implementing geometric functions in Python means working with angles. We
# are used to measure angles in ° where a full circle amounts to 360°.
# However, python calculates angles in radians (rad). This means,
# functions have to convert given or measured angles into radians. For
# this task, the `math` library offers a function: `math.radians()`.
#
# ::: {.callout-note}
#
# ## Angles in Radian Measure
#
# :::: {.columns}
#
# ::: {.column width="50%"}
#
# ![](circle.svg)
# :::
#
# ::: {.column width="50%"}
# The radian measure $\widehat{\varphi}$ of an angle is the ratio of the
# length of the circular arc cut out by the angle $\varphi$ to the radius
# of the circle. It is also denoted by $\operatorname{arc} \varphi$.
#
# $$\widehat{\varphi} = \frac{b}{r} = \operatorname{arc} \varphi =
# \frac{\pi}{180^\circ} \varphi \iff \varphi = \frac{180^\circ}{\pi}
# \widehat{\varphi}$$
#
# On the unit circle ($r=1$): $\widehat{\varphi} = b$. The unit of
# radian measure is the radian (rad). An angle of 1 rad corresponds to a
# circular arc that has the same length as the
# radius.[@durandiFormelnTabellenBegriffe2022, p. 91]
# :::
# :::
# :::

# %% [markdown]
# ## Area of a Trapezium
#
# Given the height $h$ and the parallel sides $a$ and $b$ of a Trapezium,
# ist area is calculated by the following formula:
#
# $$
# A = \frac{a+b}{2} \cdot h
# $$
#
# Implement this formula as a Python function in the cell below.

# %%
def trapezium_area(...):
    # TODO complete the code
    pass

# %%
def trapezium_area(a: float, b: float, h: float) -> float:
    return ((a + b) / 2) * h
# Out:
# [3.5, 3.5]

# %%
def does_the_student_pass(grades: list[float]) -> bool:
    sub_fours = [g - 4 for g in grades if g < 4]
    sup_fours = [g - 4 for g in grades if g >= 4]
    aggregated_sub_fours = abs(2 * sum(sub_fours))
    aggregated_sup_fours = sum(sup_fours)
    return aggregated_sub_fours <= aggregated_sup_fours

# %%
does_the_student_pass(grades)
# Out:
# False
