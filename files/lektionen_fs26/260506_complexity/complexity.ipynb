# %% [markdown]
# # Computational Complexity

# %% [markdown]
# An algorithm describes how a computer solves a problem. But usually
# there are multiple ways to solve a given problem. The ways
# differ in efficiency. The different levels of efficiency are the topic
# of computational complexity.
