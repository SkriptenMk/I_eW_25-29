# %% [markdown]
# # Image Representation on Computers

# %% [markdown]
# Images are composed of shapes and colours. This we have seen by using the PyTamaro Library. But this experince does not answer the question, how shapes and colours are represented on computers.
